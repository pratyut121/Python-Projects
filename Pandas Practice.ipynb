# %% [markdown]
# #### Reading Data in Pandas

# %%
import pandas as pd
fifa_filepath = "///Users/pratyutpannadas/downloads/r test/pokemon_data.csv"
df = pd.read_csv(fifa_filepath,index_col='#')

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail(2)
# Out:
#                    Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 720  HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 721           Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# #
# 720      130     80           6       True
# 721       90     70           6       True

# %% [markdown]
# ##### Next Item

# %%
 df.columns[0]
# Out:
# 'Name'

# %%
df['Name'][0:5]
# Out:
# #
# 1                Bulbasaur
# 2                  Ivysaur
# 3                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
df[['Name','HP']].head()
# Out:
#                     Name  HP
# #
# 1              Bulbasaur  45
# 2                Ivysaur  60
# 3               Venusaur  80
# 3  VenusaurMega Venusaur  80
# 4             Charmander  39

# %%
df.Name.head()
# Out:
# #
# 1                Bulbasaur
# 2                  Ivysaur
# 3                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
df.Name[0:5]
# Out:
# #
# 1                Bulbasaur
# 2                  Ivysaur
# 3                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
 df.iloc[0,0:3]
# Out:
# Name      Bulbasaur
# Type 1        Grass
# Type 2       Poison
# Name: 1, dtype: object

# %%
print(df.iloc[14])
# Out:
# Name          Metapod
# Type 1            Bug
# Type 2            NaN
# HP                 50
# Attack             20
# Defense            55
# Sp. Atk            25
# Sp. Def            25
# Speed              30
# Generation          1
# Legendary       False
# Name: 11, dtype: object

# %%
df.loc[(df['Type 1'] == "Grass") & (df['Attack']> 50) &(df['Type 2'] == "Flying")]
# Out:
#                  Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 189          Jumpluff  Grass  Flying   75      55       70       55       95
# 357           Tropius  Grass  Flying   99      68       83       72       87
# 492  ShayminSky Forme  Grass  Flying  100     103       75      120       75
#
#      Speed  Generation  Legendary
# #
# 189    110           2      False
# 357     51           3      False
# 492    127           4       True

# %%
df.loc[1, 'Attack']
# Out:
# 49

# %%
df.loc[3, ['Attack', 'Generation','Legendary']]
# Out:
#    Attack  Generation  Legendary
# #
# 3      82           1      False
# 3     100           1      False

# %%
cols = ['Attack', 'Generation','Legendary']
indices = [2, 5, 10, 100]

df.loc[indices, cols]
# Out:
#      Attack  Generation  Legendary
# #
# 2        62           1      False
# 5        64           1      False
# 10       30           1      False
# 100      30           1      False

# %%
df.describe()
# Out:
#                HP      Attack     Defense     Sp. Atk     Sp. Def       Speed  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean    69.258750   79.001250   73.842500   72.820000   71.902500   68.277500
# std     25.534669   32.457366   31.183501   32.722294   27.828916   29.060474
# min      1.000000    5.000000    5.000000   10.000000   20.000000    5.000000
# 25%     50.000000   55.000000   50.000000   49.750000   50.000000   45.000000
# 50%     65.000000   75.000000   70.000000   65.000000   70.000000   65.000000
# 75%     80.000000  100.000000   90.000000   95.000000   90.000000   90.000000
# max    255.000000  190.000000  230.000000  194.000000  230.000000  180.000000
#
#        Generation
# count   800.00000
# mean      3.32375
# std       1.66129
# min       1.00000
# 25%       2.00000
# 50%       3.00000
# 75%       5.00000
# max       6.00000

# %%
df.sort_values(['Type 1','HP'], ascending=[1,0])
# Out:
#                         Name Type 1    Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 469                  Yanmega    Bug    Flying  86      76       86      116
# 637                Volcarona    Bug      Fire  85      60       65      135
# 214                Heracross    Bug  Fighting  80     125       75       40
# 214  HeracrossMega Heracross    Bug  Fighting  80     185      115       40
# 617                 Accelgor    Bug       NaN  80      70       40      100
# ..                       ...    ...       ...  ..     ...      ...      ...
# 98                    Krabby  Water       NaN  30     105       90       25
# 116                   Horsea  Water       NaN  30      40       70       70
# 120                   Staryu  Water       NaN  30      45       55       70
# 129                 Magikarp  Water       NaN  20      10       55       15
# 349                   Feebas  Water       NaN  20      15       20       10
#
#      Sp. Def  Speed  Generation  Legendary
# #
# ...

# %% [markdown]
#  #### Makes changes to Data

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# #
# 1       65     45           1      False    318
# 2       80     60           1      False    405
# 3      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1              Bulbasaur  Grass  Poison      49       49       65       65
# 2                Ivysaur  Grass  Poison      62       63       80       80
# 3               Venusaur  Grass  Poison      82       83      100      100
# 3  VenusaurMega Venusaur  Grass  Poison     100      123      122      120
# 4             Charmander   Fire     NaN      52       43       60       50
#
#    Speed  Generation
# #
# 1     45           1
# 2     60           1
# 3     80           1
# 3     80           1
# 4     65           1

# %%
df= df.drop(columns=['Total'])
49+49+130+45
# Out:
# 273

# %%
df['Total']= df.iloc[:,3:9].sum(axis=1)
df
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1                Bulbasaur    Grass  Poison  45      49       49       65
# 2                  Ivysaur    Grass  Poison  60      62       63       80
# 3                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 719                Diancie     Rock   Fairy  50     100      150      100
# 719    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 720    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 720     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 721              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# #
# ...

# %%
cols= list(df.columns)
cols
df1= df[cols[0:3]+[cols[-1]]+cols[3:-1]]
df1.head(4)
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False

# %%
df1.to_csv('modified pokemon')

# %%
df1.to_excel('modified.xlsx')

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

new_df.reset_index(drop=True, inplace=True)

new_df
# Out:
#                     Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0               Venusaur  Grass  Poison   80      82       83      100
# 1  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 2              Vileplume  Grass  Poison   75      80       85      110
# 3             Victreebel  Grass  Poison   80     105       65      100
# 4              Amoonguss  Grass  Poison  114      85       70       85
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0      100     80           1      False    525
# 1      120     80           1      False    625
# 2       90     50           1      False    490
# 3       70     70           1      False    490
# 4       80     30           5      False    464

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#                           Name    Type 1    Type 2   HP  Attack  Defense  \
# #
# 3        VenusaurMega Venusaur     Grass    Poison   80     100      123
# 6    CharizardMega Charizard X      Fire    Dragon   78     130      111
# 6    CharizardMega Charizard Y      Fire    Flying   78     104       78
# 9      BlastoiseMega Blastoise     Water       NaN   79     103      120
# 15       BeedrillMega Beedrill       Bug    Poison   65     150       40
# 18         PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 65       AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 80         SlowbroMega Slowbro     Water   Psychic   95      75      180
# 94           GengarMega Gengar     Ghost    Poison   60      65       80
# 115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 127          PinsirMega Pinsir       Bug    Flying   65     155      120
# 130      GyaradosMega Gyarados     Water      Dark   95     155      109
# ...

# %%
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#                     Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur    Grass  Poison   45      49       49       65
# 2                Ivysaur    Grass  Poison   60      62       63       80
# 3               Venusaur    Grass  Poison   80      82       83      100
# 4             Charmander     Fire     NaN   39      52       43       60
# 5             Charmeleon     Fire     NaN   58      64       58       80
# ..                   ...      ...     ...  ...     ...      ...      ...
# 718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 719              Diancie     Rock   Fairy   50     100      150      100
# 720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 721            Volcanion     Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# #
# ...

# %%
import re

df.loc[df['Type 1'].str.contains('grass|fire' , flags= re.I, regex=True)]
# Out:
#                       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# #
# 1                Bulbasaur  Grass  Poison   45      49       49       65
# 2                  Ivysaur  Grass  Poison   60      62       63       80
# 3                 Venusaur  Grass  Poison   80      82       83      100
# 3    VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4               Charmander   Fire     NaN   39      52       43       60
# ..                     ...    ...     ...  ...     ...      ...      ...
# 667                 Litleo   Fire  Normal   62      50       58       73
# 668                 Pyroar   Fire  Normal   86      68       72      109
# 672                 Skiddo  Grass     NaN   66      65       48       62
# 673                 Gogoat  Grass     NaN  123     100       62       97
# 721              Volcanion   Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# #
# ...

# %%
df.loc[df['Name'].str.contains('pi[a-z]*' , flags= re.I, regex=True)]
# Out:
#                         Name    Type 1    Type 2   HP  Attack  Defense  \
# #
# 10                  Caterpie       Bug       NaN   45      30       35
# 16                    Pidgey    Normal    Flying   40      45       40
# 17                 Pidgeotto    Normal    Flying   63      60       55
# 18                   Pidgeot    Normal    Flying   83      80       75
# 18       PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 25                   Pikachu  Electric       NaN   35      55       40
# 37                    Vulpix      Fire       NaN   38      41       40
# 70                Weepinbell     Grass    Poison   65      90       50
# 78                  Rapidash      Fire       NaN   65     100       70
# 127                   Pinsir       Bug       NaN   65     125      100
# 127        PinsirMega Pinsir       Bug    Flying   65     155      120
# 167                 Spinarak       Bug    Poison   40      60       40
# ...

# %%
df.loc[df['Name'].str.contains('^pi[a-z]*' , flags= re.I, regex=True)]
# Out:
#                     Name    Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# #
# 16                Pidgey    Normal    Flying   40      45       40       35
# 17             Pidgeotto    Normal    Flying   63      60       55       50
# 18               Pidgeot    Normal    Flying   83      80       75       70
# 18   PidgeotMega Pidgeot    Normal    Flying   83      80       80      135
# 25               Pikachu  Electric       NaN   35      55       40       50
# 127               Pinsir       Bug       NaN   65     125      100       55
# 127    PinsirMega Pinsir       Bug    Flying   65     155      120       65
# 172                Pichu  Electric       NaN   20      40       15       35
# 204               Pineco       Bug       NaN   50      65       90       35
# 221            Piloswine       Ice    Ground  100     100       80       60
# 393               Piplup     Water       NaN   53      51       53       61
# ...

# %%
df.loc[df['Name'].str.contains('pi[a-z]' , flags= re.I, regex=True)]
# Out:
#                         Name    Type 1    Type 2   HP  Attack  Defense  \
# #
# 10                  Caterpie       Bug       NaN   45      30       35
# 16                    Pidgey    Normal    Flying   40      45       40
# 17                 Pidgeotto    Normal    Flying   63      60       55
# 18                   Pidgeot    Normal    Flying   83      80       75
# 18       PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 25                   Pikachu  Electric       NaN   35      55       40
# 37                    Vulpix      Fire       NaN   38      41       40
# 70                Weepinbell     Grass    Poison   65      90       50
# 78                  Rapidash      Fire       NaN   65     100       70
# 127                   Pinsir       Bug       NaN   65     125      100
# 127        PinsirMega Pinsir       Bug    Flying   65     155      120
# 167                 Spinarak       Bug    Poison   40      60       40
# ...

# %% [markdown]
# #### Conditional Changes

# %%
df1.loc[df1['Type 1']=='Fire', 'Type 1']='flamer'

df1
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander   flamer     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion   flamer   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
df1.loc[df1['Type 1']=='flamer',"Legendary" ]=True

df1
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander   flamer     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion   flamer   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
df1.loc[df1['Total'] > 500, ['Generation','Legendary']] = ['Test 1', 'Test 2']

df1
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander   flamer     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion   flamer   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed Generation Legendary
# #
# ...

# %%
df.groupby(['Type 1','Type 2']).mean().sort_values('Attack',ascending= False)
# Out:
#                           HP      Attack     Defense     Sp. Atk     Sp. Def  \
# Type 1  Type 2
# Ground  Fire      100.000000  180.000000  160.000000  150.000000   90.000000
# Psychic Fighting   80.666667  160.000000   86.666667   94.666667  110.000000
#         Dark       80.000000  160.000000   60.000000  170.000000  130.000000
# Bug     Fighting   80.000000  155.000000   95.000000   40.000000  100.000000
# Dragon  Electric  100.000000  150.000000  120.000000  120.000000  100.000000
# ...                      ...         ...         ...         ...         ...
# Fairy   Flying     70.000000   45.000000   90.000000  100.000000  110.000000
# Ghost   Fire       56.666667   41.666667   68.333333  101.666667   68.333333
# Ice     Psychic    55.000000   40.000000   25.000000  100.000000   80.000000
# Water   Fairy      85.000000   35.000000   65.000000   40.000000   65.000000
# Bug     Water      40.000000   30.000000   32.000000   50.000000   52.000000
#
# ...

# %%
df.groupby('Type 1').count()
# Out:
#           Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug         69      52   69      69       69       69       69     69
# Dark        31      21   31      31       31       31       31     31
# Dragon      32      21   32      32       32       32       32     32
# Electric    44      17   44      44       44       44       44     44
# Fairy       17       2   17      17       17       17       17     17
# Fighting    27       7   27      27       27       27       27     27
# Fire        52      24   52      52       52       52       52     52
# Flying       4       2    4       4        4        4        4      4
# Ghost       32      22   32      32       32       32       32     32
# Grass       70      37   70      70       70       70       70     70
# Ground      32      19   32      32       32       32       32     32
# Ice         24      11   24      24       24       24       24     24
# ...
